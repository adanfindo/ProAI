# %% [markdown]
# # Teoria

# %% [markdown]
# ## Clustering vs Classificazione

# %% [markdown]
# apprendimento non supervisionato.
# <br> raggruppa osservazioni in base a caratteristiche simili
# <br> si differenzia da classificazione perchè non ho output (aka label), ad esempio classificare clienti di un super mercato

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# un modello di clustering raggruppa le classi in base alle loro caratteristiche <br>
# il significato del cluster va trovato con tecniche che vanno oltre la creazione del modello

# %% [markdown]
# ## Algoritmo K means

# %% [markdown]
# raggruppare osservazioni in base a loro caratteristiche

# %% [markdown]
# ### how it works
# 1. scelgo k cluster da creare
# 2. scelgo causalmente k centroide (1 per ogni cluster), punto centrale del cluster
# 3. calcolo distanza tra centroide e obs di ogni classe
# 4. assegno le obs al cluster rappresentato dal centroide più vicino
# 5. ricalcolo i centroidi come media delle classi che si sono create
# 6. ripeto dal punto 2 finchè nessuna osservazione cambia classe

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
- parto da un dataset visualizzato in scatter plot
- da un punto di vista visivo sembra di visualizare 4 cluster
-
